# %%
import pandas as pd
from sklearn.model_selection import train_test_split
morgan_dataset = pd.read_csv("~/datasets/morgan_dataset.csv")
ap_dataset = pd.read_csv("~/datasets/ap_dataset.csv")
rdk5_dataset = pd.read_csv("~/datasets/rdk5_dataset.csv")

# %%
# Ensure datasets are aligned (optional if already aligned)
morgan_dataset, ap_dataset = morgan_dataset.align(ap_dataset, join='inner', axis=0)
morgan_dataset, rdk5_dataset = morgan_dataset.align(rdk5_dataset, join='inner', axis=0)

# Split morgan_dataset into training and testing sets (80% train, 20% test)
morgan_train, morgan_test = train_test_split(morgan_dataset, test_size=0.2, random_state=42)

# Now split ap_dataset and rdk5_dataset based on the indices of the split
ap_train = ap_dataset.loc[morgan_train.index]  # Use the same indices from morgan_train
ap_test = ap_dataset.loc[morgan_test.index]  # Use the same indices from morgan_test

rdk5_train = rdk5_dataset.loc[morgan_train.index]  # Use the same indices from morgan_train
rdk5_test = rdk5_dataset.loc[morgan_test.index]  # Use the same indices from morgan_test

# Split based on 'activity' as the target
X_morgan_train_activity = morgan_train.drop(columns=['activity', 'pIC50'])
y_morgan_train_activity = morgan_train['activity']

X_morgan_test_activity = morgan_test.drop(columns=['activity', 'pIC50'])
y_morgan_test_activity = morgan_test['activity']

X_ap_train_activity = ap_train.drop(columns=['activity', 'pIC50'])
y_ap_train_activity = ap_train['activity']

X_ap_test_activity = ap_test.drop(columns=['activity', 'pIC50'])
y_ap_test_activity = ap_test['activity']

X_rdk5_train_activity = rdk5_train.drop(columns=['activity', 'pIC50'])
y_rdk5_train_activity = rdk5_train['activity']

X_rdk5_test_activity = rdk5_test.drop(columns=['activity', 'pIC50'])
y_rdk5_test_activity = rdk5_test['activity']

# %%
import os
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)
from typing import Tuple

def run_classifiers(
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    y_train: pd.Series,
    y_test: pd.Series,
    num_trials: int,
    save_dir: str
) -> None:
    """
    Runs multiple classifiers for a specified number of trials and saves multiple evaluation metrics.

    Metrics include:
    - Accuracy
    - Precision (macro)
    - Recall (macro)
    - F1-score (macro)
    - ROC AUC (if binary classification)

    Args:
        X_train (pd.DataFrame): Training feature set.
        X_test (pd.DataFrame): Testing feature set.
        y_train (pd.Series): Training labels.
        y_test (pd.Series): Testing labels.
        num_trials (int): Number of times to train each classifier.
        save_dir (str): Directory to save accuracy results.

    Raises:
        ValueError: If num_trials is less than 1.
        FileNotFoundError: If save_dir does not exist.
    """
    if num_trials < 1:
        raise ValueError("num_trials must be at least 1.")

    if not os.path.exists(save_dir):
        os.makedirs(save_dir)  # Create directory if missing

    classifiers = {
        "Logistic Regression": LogisticRegression(),
        "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
        "SVM": SVC(kernel="linear", random_state=42, probability=True),
        "Gradient Boosting": GradientBoostingClassifier(random_state=42),
        "KNN": KNeighborsClassifier(),
    }

    results = []

    for trial in range(1, num_trials + 1):
        print(f"Running Trial {trial}...")
        
        for name, model in classifiers.items():
            print(f"Training {name}...")
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            metrics = {
                "Trial": trial,
                "Model": name,
                "Accuracy": accuracy_score(y_test, y_pred),
                "Precision": precision_score(y_test, y_pred, average="macro", zero_division=0),
                "Recall": recall_score(y_test, y_pred, average="macro"),
                "F1-score": f1_score(y_test, y_pred, average="macro"),
            }

            # Compute ROC AUC only if binary classification
            if len(y_test.unique()) == 2 and hasattr(model, "predict_proba"):
                y_prob = model.predict_proba(X_test)[:, 1]  # Get probabilities for positive class
                metrics["ROC AUC"] = roc_auc_score(y_test, y_prob)
            else:
                metrics["ROC AUC"] = None

            print(f"{name} Results (Trial {trial}): {metrics}")
            results.append(metrics)

    # Convert results to DataFrame and save
    results_df = pd.DataFrame(results)
    results_csv_path = os.path.join(save_dir, "classifier_metrics_results.csv")
    results_df.to_csv(results_csv_path, index=False)

    print(f"All trials completed. Results saved to {results_csv_path}.")

# %%
import os
os.makedirs(os.path.expanduser("~/datasets/control"), exist_ok=True)
os.makedirs(os.path.expanduser("~/datasets/control/morgan"), exist_ok=True)
os.makedirs(os.path.expanduser("~/datasets/control/ap"), exist_ok=True)
os.makedirs(os.path.expanduser("~/datasets/control/rdk5"), exist_ok=True)

# %%
run_classifiers(
    X_morgan_train_activity,
    X_morgan_test_activity,
    y_morgan_train_activity,
    y_morgan_test_activity,
    num_trials=40,
    save_dir="~/datasets/control/morgan"
)
# Out:
# Running Trial 1...
# Training Logistic Regression...
# Logistic Regression Results (Trial 1): {'Trial': 1, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 1): {'Trial': 1, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 1): {'Trial': 1, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 1): {'Trial': 1, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 1): {'Trial': 1, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 2...
# Training Logistic Regression...
# Logistic Regression Results (Trial 2): {'Trial': 2, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 2): {'Trial': 2, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 2): {'Trial': 2, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 2): {'Trial': 2, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 2): {'Trial': 2, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 3...
# Training Logistic Regression...
# Logistic Regression Results (Trial 3): {'Trial': 3, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 3): {'Trial': 3, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 3): {'Trial': 3, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 3): {'Trial': 3, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 3): {'Trial': 3, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 4...
# Training Logistic Regression...
# Logistic Regression Results (Trial 4): {'Trial': 4, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 4): {'Trial': 4, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 4): {'Trial': 4, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 4): {'Trial': 4, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 4): {'Trial': 4, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 5...
# Training Logistic Regression...
# Logistic Regression Results (Trial 5): {'Trial': 5, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 5): {'Trial': 5, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 5): {'Trial': 5, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 5): {'Trial': 5, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 5): {'Trial': 5, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 6...
# Training Logistic Regression...
# Logistic Regression Results (Trial 6): {'Trial': 6, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 6): {'Trial': 6, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 6): {'Trial': 6, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 6): {'Trial': 6, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 6): {'Trial': 6, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 7...
# Training Logistic Regression...
# Logistic Regression Results (Trial 7): {'Trial': 7, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 7): {'Trial': 7, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 7): {'Trial': 7, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 7): {'Trial': 7, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 7): {'Trial': 7, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 8...
# Training Logistic Regression...
# Logistic Regression Results (Trial 8): {'Trial': 8, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 8): {'Trial': 8, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 8): {'Trial': 8, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 8): {'Trial': 8, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 8): {'Trial': 8, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 9...
# Training Logistic Regression...
# Logistic Regression Results (Trial 9): {'Trial': 9, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 9): {'Trial': 9, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 9): {'Trial': 9, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 9): {'Trial': 9, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 9): {'Trial': 9, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 10...
# Training Logistic Regression...
# Logistic Regression Results (Trial 10): {'Trial': 10, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 10): {'Trial': 10, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 10): {'Trial': 10, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 10): {'Trial': 10, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 10): {'Trial': 10, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 11...
# Training Logistic Regression...
# Logistic Regression Results (Trial 11): {'Trial': 11, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 11): {'Trial': 11, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 11): {'Trial': 11, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 11): {'Trial': 11, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 11): {'Trial': 11, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 12...
# Training Logistic Regression...
# Logistic Regression Results (Trial 12): {'Trial': 12, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 12): {'Trial': 12, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 12): {'Trial': 12, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 12): {'Trial': 12, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 12): {'Trial': 12, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 13...
# Training Logistic Regression...
# Logistic Regression Results (Trial 13): {'Trial': 13, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 13): {'Trial': 13, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 13): {'Trial': 13, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 13): {'Trial': 13, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 13): {'Trial': 13, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 14...
# Training Logistic Regression...
# Logistic Regression Results (Trial 14): {'Trial': 14, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 14): {'Trial': 14, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 14): {'Trial': 14, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 14): {'Trial': 14, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 14): {'Trial': 14, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 15...
# Training Logistic Regression...
# Logistic Regression Results (Trial 15): {'Trial': 15, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 15): {'Trial': 15, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 15): {'Trial': 15, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 15): {'Trial': 15, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 15): {'Trial': 15, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 16...
# Training Logistic Regression...
# Logistic Regression Results (Trial 16): {'Trial': 16, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 16): {'Trial': 16, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 16): {'Trial': 16, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 16): {'Trial': 16, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 16): {'Trial': 16, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 17...
# Training Logistic Regression...
# Logistic Regression Results (Trial 17): {'Trial': 17, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 17): {'Trial': 17, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 17): {'Trial': 17, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 17): {'Trial': 17, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 17): {'Trial': 17, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 18...
# Training Logistic Regression...
# Logistic Regression Results (Trial 18): {'Trial': 18, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 18): {'Trial': 18, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 18): {'Trial': 18, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 18): {'Trial': 18, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 18): {'Trial': 18, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 19...
# Training Logistic Regression...
# Logistic Regression Results (Trial 19): {'Trial': 19, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 19): {'Trial': 19, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 19): {'Trial': 19, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 19): {'Trial': 19, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 19): {'Trial': 19, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 20...
# Training Logistic Regression...
# Logistic Regression Results (Trial 20): {'Trial': 20, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 20): {'Trial': 20, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 20): {'Trial': 20, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 20): {'Trial': 20, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 20): {'Trial': 20, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 21...
# Training Logistic Regression...
# Logistic Regression Results (Trial 21): {'Trial': 21, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 21): {'Trial': 21, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 21): {'Trial': 21, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 21): {'Trial': 21, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 21): {'Trial': 21, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 22...
# Training Logistic Regression...
# Logistic Regression Results (Trial 22): {'Trial': 22, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 22): {'Trial': 22, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 22): {'Trial': 22, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 22): {'Trial': 22, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 22): {'Trial': 22, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 23...
# Training Logistic Regression...
# Logistic Regression Results (Trial 23): {'Trial': 23, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 23): {'Trial': 23, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 23): {'Trial': 23, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 23): {'Trial': 23, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 23): {'Trial': 23, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 24...
# Training Logistic Regression...
# Logistic Regression Results (Trial 24): {'Trial': 24, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 24): {'Trial': 24, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 24): {'Trial': 24, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 24): {'Trial': 24, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 24): {'Trial': 24, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 25...
# Training Logistic Regression...
# Logistic Regression Results (Trial 25): {'Trial': 25, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 25): {'Trial': 25, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 25): {'Trial': 25, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 25): {'Trial': 25, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 25): {'Trial': 25, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 26...
# Training Logistic Regression...
# Logistic Regression Results (Trial 26): {'Trial': 26, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 26): {'Trial': 26, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 26): {'Trial': 26, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 26): {'Trial': 26, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 26): {'Trial': 26, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 27...
# Training Logistic Regression...
# Logistic Regression Results (Trial 27): {'Trial': 27, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 27): {'Trial': 27, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 27): {'Trial': 27, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 27): {'Trial': 27, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 27): {'Trial': 27, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 28...
# Training Logistic Regression...
# Logistic Regression Results (Trial 28): {'Trial': 28, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 28): {'Trial': 28, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 28): {'Trial': 28, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 28): {'Trial': 28, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 28): {'Trial': 28, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 29...
# Training Logistic Regression...
# Logistic Regression Results (Trial 29): {'Trial': 29, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 29): {'Trial': 29, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 29): {'Trial': 29, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 29): {'Trial': 29, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 29): {'Trial': 29, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 30...
# Training Logistic Regression...
# Logistic Regression Results (Trial 30): {'Trial': 30, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 30): {'Trial': 30, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 30): {'Trial': 30, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 30): {'Trial': 30, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 30): {'Trial': 30, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 31...
# Training Logistic Regression...
# Logistic Regression Results (Trial 31): {'Trial': 31, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 31): {'Trial': 31, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 31): {'Trial': 31, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 31): {'Trial': 31, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 31): {'Trial': 31, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 32...
# Training Logistic Regression...
# Logistic Regression Results (Trial 32): {'Trial': 32, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 32): {'Trial': 32, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 32): {'Trial': 32, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 32): {'Trial': 32, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 32): {'Trial': 32, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 33...
# Training Logistic Regression...
# Logistic Regression Results (Trial 33): {'Trial': 33, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 33): {'Trial': 33, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 33): {'Trial': 33, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 33): {'Trial': 33, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 33): {'Trial': 33, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 34...
# Training Logistic Regression...
# Logistic Regression Results (Trial 34): {'Trial': 34, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 34): {'Trial': 34, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 34): {'Trial': 34, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 34): {'Trial': 34, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 34): {'Trial': 34, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 35...
# Training Logistic Regression...
# Logistic Regression Results (Trial 35): {'Trial': 35, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 35): {'Trial': 35, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 35): {'Trial': 35, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 35): {'Trial': 35, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 35): {'Trial': 35, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 36...
# Training Logistic Regression...
# Logistic Regression Results (Trial 36): {'Trial': 36, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 36): {'Trial': 36, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 36): {'Trial': 36, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 36): {'Trial': 36, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 36): {'Trial': 36, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 37...
# Training Logistic Regression...
# Logistic Regression Results (Trial 37): {'Trial': 37, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 37): {'Trial': 37, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 37): {'Trial': 37, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 37): {'Trial': 37, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 37): {'Trial': 37, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 38...
# Training Logistic Regression...
# Logistic Regression Results (Trial 38): {'Trial': 38, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 38): {'Trial': 38, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 38): {'Trial': 38, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 38): {'Trial': 38, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 38): {'Trial': 38, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 39...
# Training Logistic Regression...
# Logistic Regression Results (Trial 39): {'Trial': 39, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 39): {'Trial': 39, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 39): {'Trial': 39, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 39): {'Trial': 39, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 39): {'Trial': 39, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# Running Trial 40...
# Training Logistic Regression...
# Logistic Regression Results (Trial 40): {'Trial': 40, 'Model': 'Logistic Regression', 'Accuracy': 0.9170731707317074, 'Precision': 0.8210141813493769, 'Recall': 0.8108614232209738, 'F1-score': 0.8158131176999102, 'ROC AUC': 0.9453287557220141}
# Training Random Forest...
# Random Forest Results (Trial 40): {'Trial': 40, 'Model': 'Random Forest', 'Accuracy': 0.926829268292683, 'Precision': 0.8463888888888889, 'Recall': 0.8243341656263005, 'F1-score': 0.8348195100988397, 'ROC AUC': 0.9552642530170619}
# Training SVM...
# SVM Results (Trial 40): {'Trial': 40, 'Model': 'SVM', 'Accuracy': 0.9048780487804878, 'Precision': 0.7870197119359471, 'Recall': 0.8431127756970453, 'F1-score': 0.810945979498457, 'ROC AUC': 0.9316999583853517}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 40): {'Trial': 40, 'Model': 'Gradient Boosting', 'Accuracy': 0.9195121951219513, 'Precision': 0.8341539182931833, 'Recall': 0.7965563878485227, 'F1-score': 0.81368512372795, 'ROC AUC': 0.9439502704952143}
# Training KNN...
# KNN Results (Trial 40): {'Trial': 40, 'Model': 'KNN', 'Accuracy': 0.9146341463414634, 'Precision': 0.8091409532087499, 'Recall': 0.8330212234706617, 'F1-score': 0.8203802681153071, 'ROC AUC': 0.9233770287141074}
# All trials completed. Results saved to ~/datasets/control/morgan/classifier_metrics_results.csv.

# %%
run_classifiers(
    X_ap_train_activity,
    X_ap_test_activity,
    y_ap_train_activity,
    y_ap_test_activity,
    num_trials=40,
    save_dir="~/datasets/control/ap"
)
# Out:
# Running Trial 1...
# Training Logistic Regression...
# Logistic Regression Results (Trial 1): {'Trial': 1, 'Model': 'Logistic Regression', 'Accuracy': 0.9146341463414634, 'Precision': 0.8144125574758205, 'Recall': 0.8094569288389513, 'F1-score': 0.8119044186076995, 'ROC AUC': 0.9386704119850189}
# Training Random Forest...
# Random Forest Results (Trial 1): {'Trial': 1, 'Model': 'Random Forest', 'Accuracy': 0.9195121951219513, 'Precision': 0.8378995433789954, 'Recall': 0.788701622971286, 'F1-score': 0.8104484512251502, 'ROC AUC': 0.9547440699126092}
# Training SVM...
# SVM Results (Trial 1): {'Trial': 1, 'Model': 'SVM', 'Accuracy': 0.9073170731707317, 'Precision': 0.794817789968652, 'Recall': 0.8130982105701208, 'F1-score': 0.8035209846650524, 'ROC AUC': 0.9147419891801913}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 1): {'Trial': 1, 'Model': 'Gradient Boosting', 'Accuracy': 0.9146341463414634, 'Precision': 0.8291299664153096, 'Recall': 0.7701831044527674, 'F1-score': 0.7953829262380402, 'ROC AUC': 0.9525593008739076}
# Training KNN...
# KNN Results (Trial 1): {'Trial': 1, 'Model': 'KNN', 'Accuracy': 0.9365853658536586, 'Precision': 0.8650623119896863, 'Recall': 0.8535164377861006, 'F1-score': 0.8591512076528725, 'ROC AUC': 0.9365376612567624}
# Running Trial 2...
# Training Logistic Regression...
# Logistic Regression Results (Trial 2): {'Trial': 2, 'Model': 'Logistic Regression', 'Accuracy': 0.9146341463414634, 'Precision': 0.8144125574758205, 'Recall': 0.8094569288389513, 'F1-score': 0.8119044186076995, 'ROC AUC': 0.9386704119850189}
# Training Random Forest...
# Random Forest Results (Trial 2): {'Trial': 2, 'Model': 'Random Forest', 'Accuracy': 0.9195121951219513, 'Precision': 0.8378995433789954, 'Recall': 0.788701622971286, 'F1-score': 0.8104484512251502, 'ROC AUC': 0.9547440699126092}
# Training SVM...
# SVM Results (Trial 2): {'Trial': 2, 'Model': 'SVM', 'Accuracy': 0.9073170731707317, 'Precision': 0.794817789968652, 'Recall': 0.8130982105701208, 'F1-score': 0.8035209846650524, 'ROC AUC': 0.9147419891801913}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 2): {'Trial': 2, 'Model': 'Gradient Boosting', 'Accuracy': 0.9146341463414634, 'Precision': 0.8291299664153096, 'Recall': 0.7701831044527674, 'F1-score': 0.7953829262380402, 'ROC AUC': 0.9525593008739076}
# Training KNN...
# KNN Results (Trial 2): {'Trial': 2, 'Model': 'KNN', 'Accuracy': 0.9365853658536586, 'Precision': 0.8650623119896863, 'Recall': 0.8535164377861006, 'F1-score': 0.8591512076528725, 'ROC AUC': 0.9365376612567624}
# Running Trial 3...
# Training Logistic Regression...
# Logistic Regression Results (Trial 3): {'Trial': 3, 'Model': 'Logistic Regression', 'Accuracy': 0.9146341463414634, 'Precision': 0.8144125574758205, 'Recall': 0.8094569288389513, 'F1-score': 0.8119044186076995, 'ROC AUC': 0.9386704119850189}
# Training Random Forest...
# Random Forest Results (Trial 3): {'Trial': 3, 'Model': 'Random Forest', 'Accuracy': 0.9195121951219513, 'Precision': 0.8378995433789954, 'Recall': 0.788701622971286, 'F1-score': 0.8104484512251502, 'ROC AUC': 0.9547440699126092}
# Training SVM...
# SVM Results (Trial 3): {'Trial': 3, 'Model': 'SVM', 'Accuracy': 0.9073170731707317, 'Precision': 0.794817789968652, 'Recall': 0.8130982105701208, 'F1-score': 0.8035209846650524, 'ROC AUC': 0.9147419891801913}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 3): {'Trial': 3, 'Model': 'Gradient Boosting', 'Accuracy': 0.9146341463414634, 'Precision': 0.8291299664153096, 'Recall': 0.7701831044527674, 'F1-score': 0.7953829262380402, 'ROC AUC': 0.9525593008739076}
# Training KNN...
# KNN Results (Trial 3): {'Trial': 3, 'Model': 'KNN', 'Accuracy': 0.9365853658536586, 'Precision': 0.8650623119896863, 'Recall': 0.8535164377861006, 'F1-score': 0.8591512076528725, 'ROC AUC': 0.9365376612567624}
# Running Trial 4...
# Training Logistic Regression...
# Logistic Regression Results (Trial 4): {'Trial': 4, 'Model': 'Logistic Regression', 'Accuracy': 0.9146341463414634, 'Precision': 0.8144125574758205, 'Recall': 0.8094569288389513, 'F1-score': 0.8119044186076995, 'ROC AUC': 0.9386704119850189}
# Training Random Forest...
# Random Forest Results (Trial 4): {'Trial': 4, 'Model': 'Random Forest', 'Accuracy': 0.9195121951219513, 'Precision': 0.8378995433789954, 'Recall': 0.788701622971286, 'F1-score': 0.8104484512251502, 'ROC AUC': 0.9547440699126092}
# Training SVM...
# SVM Results (Trial 4): {'Trial': 4, 'Model': 'SVM', 'Accuracy': 0.9073170731707317, 'Precision': 0.794817789968652, 'Recall': 0.8130982105701208, 'F1-score': 0.8035209846650524, 'ROC AUC': 0.9147419891801913}
# Training Gradient Boosting...
# Gradient Boosting Results (Trial 4): {'Trial': 4, 'Model': 'Gradient Boosting', 'Accuracy': 0.9146341463414634, 'Precision': 0.8291299664153096, 'Recall': 0.7701831044527674, 'F1-score': 0.7953829262380402, 'ROC AUC': 0.9525593008739076}
# Training KNN...
# KNN Results (Trial 4): {'Trial': 4, 'Model': 'KNN', 'Accuracy': 0.9365853658536586, 'Precision': 0.8650623119896863, 'Recall': 0.8535164377861006, 'F1-score': 0.8591512076528725, 'ROC AUC': 0.9365376612567624}
# Running Trial 5...
# Training Logistic Regression...
# Logistic Regression Results (Trial 5): {'Trial': 5, 'Model': 'Logistic Regression', 'Accuracy': 0.9146341463414634, 'Precision': 0.8144125574758205, 'Recall': 0.8094569288389513, 'F1-score': 0.8119044186076995, 'ROC AUC': 0.9386704119850189}
# Training Random Forest...
# Random Forest Results (Trial 5): {'Trial': 5, 'Model': 'Random Forest', 'Accuracy': 0.9195121951219513, 'Precision': 0.8378995433789954, 'Recall': 0.788701622971286, 'F1-score': 0.8104484512251502, 'ROC AUC': 0.9547440699126092}
# Training SVM...

# %%
run_classifiers(
    X_rdk5_train_activity,
    X_rdk5_test_activity,
    y_rdk5_train_activity,
    y_rdk5_test_activity,
    num_trials=40,
    save_dir="~/datasets/control/rdk5"
)
